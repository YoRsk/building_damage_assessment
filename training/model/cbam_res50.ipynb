# %%
from torchsummary import summary
import torch
from cbam_res50 import ResNet50

model = ResNet50(use_cbam=True, image_depth=3, num_classes=3).cuda()

# 打印模型摘要
summary(model, (3, 224, 224), device='cuda')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#           Flatten-13                  [-1, 256]               0
# ...

# %%
import torchvision.models as models
model = models.resnet50().cuda()
summary(model, (3, 224, 224), device='cuda')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
# ...

# %%
from my_models import SiameseUNetWithResnet50Encoder

model = SiameseUNetWithResnet50Encoder(n_classes=5).cuda()
# 注意：由于这是一个孪生网络，我们需要为两个输入各自指定一个形状
summary(model, [(3, 224, 224), (3, 224, 224)], device='cuda')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#             Conv2d-4         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-5         [-1, 64, 112, 112]             128
#               ReLU-6         [-1, 64, 112, 112]               0
#          MaxPool2d-7           [-1, 64, 56, 56]               0
#          MaxPool2d-8           [-1, 64, 56, 56]               0
#             Conv2d-9           [-1, 64, 56, 56]           4,096
#       BatchNorm2d-10           [-1, 64, 56, 56]             128
#              ReLU-11           [-1, 64, 56, 56]               0
#            Conv2d-12           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-13           [-1, 64, 56, 56]             128
# ...
